# %% [markdown]
# <a href="https://colab.research.google.com/github/septianidn/APM_11/blob/main/Pertemuan%205/K_Means_Elbows_Silhouette.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn import metrics
from sklearn.cluster import KMeans
from sklearn.preprocessing import StandardScaler
import warnings
warnings.filterwarnings("ignore")
# %matplotlib inline

# %%
df_country = pd.read_csv('Country-data.csv', sep=",", encoding="ISO-8859-1", header=0)
df_country.head()
# Out:
#                country  child_mort  exports  health  imports  income  \
# 0          Afghanistan        90.2     10.0    7.58     44.9    1610
# 1              Albania        16.6     28.0    6.55     48.6    9930
# 2              Algeria        27.3     38.4    4.17     31.4   12900
# 3               Angola       119.0     62.3    2.85     42.9    5900
# 4  Antigua and Barbuda        10.3     45.5    6.03     58.9   19100
#
#    inflation  life_expec  total_fer   gdpp
# 0       9.44        56.2       5.82    553
# 1       4.49        76.3       1.65   4090
# 2      16.10        76.5       2.89   4460
# 3      22.40        60.1       6.16   3530
# 4       1.44        76.8       2.13  12200

# %%
df_country.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 167 entries, 0 to 166
# Data columns (total 10 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   country     167 non-null    object
#  1   child_mort  167 non-null    float64
#  2   exports     167 non-null    float64
#  3   health      167 non-null    float64
#  4   imports     167 non-null    float64
#  5   income      167 non-null    int64
#  6   inflation   167 non-null    float64
#  7   life_expec  167 non-null    float64
#  8   total_fer   167 non-null    float64
#  9   gdpp        167 non-null    int64
# dtypes: float64(7), int64(2), object(1)
# memory usage: 13.2+ KB

# %%
df_country.shape
# Out:
# (167, 10)

# %%
df_country.describe()
# Out:
#        child_mort     exports      health     imports         income  \
# count  167.000000  167.000000  167.000000  167.000000     167.000000
# mean    38.270060   41.108976    6.815689   46.890215   17144.688623
# std     40.328931   27.412010    2.746837   24.209589   19278.067698
# min      2.600000    0.109000    1.810000    0.065900     609.000000
# 25%      8.250000   23.800000    4.920000   30.200000    3355.000000
# 50%     19.300000   35.000000    6.320000   43.300000    9960.000000
# 75%     62.100000   51.350000    8.600000   58.750000   22800.000000
# max    208.000000  200.000000   17.900000  174.000000  125000.000000
#
#         inflation  life_expec   total_fer           gdpp
# count  167.000000  167.000000  167.000000     167.000000
# mean     7.781832   70.555689    2.947964   12964.155689
# std     10.570704    8.893172    1.513848   18328.704809
# min     -4.210000   32.100000    1.150000     231.000000
# 25%      1.810000   65.300000    1.795000    1330.000000
# ...

# %%
df_country.isnull().sum()
# Out:
# country       0
# child_mort    0
# exports       0
# health        0
# imports       0
# income        0
# inflation     0
# life_expec    0
# total_fer     0
# gdpp          0
# dtype: int64

# %%
df_dict = pd.read_csv('data-dictionary.csv', sep=",", encoding="ISO-8859-1", header=0)
df_dict.head(10)
# Out:
#   ï»¿Column Name                                        Description
# 0        country                                Name of the country
# 1     child_mort  Death of children under 5 years of age per 100...
# 2        exports  Exports of goods and services per capita. Give...
# 3         health  Total health spending per capita. Given as %ag...
# 4        imports  Imports of goods and services per capita. Give...
# 5         Income                              Net income per person
# 6      Inflation  The measurement of the annual growth rate of t...
# 7     life_expec  The average number of years a new born child w...
# 8      total_fer  The number of children that would be born to e...
# 9           gdpp  The GDP per capita. Calculated as the Total GD...

# %%
df_dict.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10 entries, 0 to 9
# Data columns (total 2 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   ï»¿Column Name  10 non-null     object
#  1   Description     10 non-null     object
# dtypes: object(2)
# memory usage: 288.0+ bytes

# %%
df_dict.shape
# Out:
# (10, 2)

# %%
df_dict.isnull().sum()
# Out:
# ï»¿Column Name    0
# Description       0
# dtype: int64

# %%
#jumlah negara pada data
df_country['country'].nunique()
# Out:
# 167

# %%
# Drop "Country" kolom
data = df_country.drop('country', axis=1)

# %%
data.head()
# Out:
#    child_mort  exports  health  imports  income  inflation  life_expec  \
# 0        90.2     10.0    7.58     44.9    1610       9.44        56.2
# 1        16.6     28.0    6.55     48.6    9930       4.49        76.3
# 2        27.3     38.4    4.17     31.4   12900      16.10        76.5
# 3       119.0     62.3    2.85     42.9    5900      22.40        60.1
# 4        10.3     45.5    6.03     58.9   19100       1.44        76.8
#
#    total_fer   gdpp
# 0       5.82    553
# 1       1.65   4090
# 2       2.89   4460
# 3       6.16   3530
# 4       2.13  12200

# %%
corr_matrix=data.corr()
sns.heatmap(corr_matrix,annot=True)

# %%
sns.pairplot(data)

# %% [markdown]
# ### Scaling Data

# %%
scaling=StandardScaler()
scaled=scaling.fit_transform(data)

# %%
scaled_df=pd.DataFrame(scaled,columns=data.columns)

# princt scaled dataset
scaled_df.head()
# Out:
#    child_mort   exports    health   imports    income  inflation  life_expec  \
# 0    1.291532 -1.138280  0.279088 -0.082455 -0.808245   0.157336   -1.619092
# 1   -0.538949 -0.479658 -0.097016  0.070837 -0.375369  -0.312347    0.647866
# 2   -0.272833 -0.099122 -0.966073 -0.641762 -0.220844   0.789274    0.670423
# 3    2.007808  0.775381 -1.448071 -0.165315 -0.585043   1.387054   -1.179234
# 4   -0.695634  0.160668 -0.286894  0.497568  0.101732  -0.601749    0.704258
#
#    total_fer      gdpp
# 0   1.902882 -0.679180
# 1  -0.859973 -0.485623
# 2  -0.038404 -0.465376
# 3   2.128151 -0.516268
# 4  -0.541946 -0.041817

# %% [markdown]
# ### K-Means Clustering

# %% [markdown]
# #### Metode Elbow

# %%
# plot elbow curve

a=[]
K=range(1,10)
for i in K:
    kmean=KMeans(n_clusters=i)
    kmean.fit(data)
    a.append(kmean.inertia_)
    
plt.plot(K,a,marker='o')
plt.title('Elbow Method',fontsize=15)
plt.xlabel('Number of clusters',fontsize=15)
plt.ylabel('Sum of Squared distance',fontsize=15)
plt.show()

# %%
#Memilih cluster 3 dan fitting model
kmeans = KMeans(n_clusters = 3,random_state = 111)
kmeans.fit(scaled_df)
# Out:
# KMeans(n_clusters=3, random_state=111)

# %%
#Menghitung jumlah record setiap kluster
pd.Series(kmeans.labels_).value_counts()
# Out:
# 2    84
# 0    47
# 1    36
# dtype: int64

# %% [markdown]
# #### Metode Silhouette

# %%
#Menghitung koefisien silhoutter untuk K=3 

metrics.silhouette_score(scaled_df, kmeans.labels_)
# Out:
# 0.28329575683463126

# %% [markdown]
# ### Prediksi

# %%
#predicting values
cluster_labels = kmeans.fit_predict(scaled_df)

# %%
preds = kmeans.labels_
kmeans_df = pd.DataFrame(df_country)
kmeans_df['KMeans_Clusters'] = preds
kmeans_df.head(10)
# Out:
#                country  child_mort  exports  health  imports  income  \
# 0          Afghanistan        90.2     10.0    7.58     44.9    1610
# 1              Albania        16.6     28.0    6.55     48.6    9930
# 2              Algeria        27.3     38.4    4.17     31.4   12900
# 3               Angola       119.0     62.3    2.85     42.9    5900
# 4  Antigua and Barbuda        10.3     45.5    6.03     58.9   19100
# 5            Argentina        14.5     18.9    8.10     16.0   18700
# 6              Armenia        18.1     20.8    4.40     45.3    6700
# 7            Australia         4.8     19.8    8.73     20.9   41400
# 8              Austria         4.3     51.3   11.00     47.8   43200
# 9           Azerbaijan        39.2     54.3    5.88     20.7   16000
#
#    inflation  life_expec  total_fer   gdpp  KMeans_Clusters
# 0      9.440        56.2       5.82    553                0
# 1      4.490        76.3       1.65   4090                2
# ...

# %%
kmeans_df.to_csv('kmeans_result.csv',index=False)

# %% [markdown]
# #### Visualisasi dari CLustering

# %%
sns.scatterplot(kmeans_df['child_mort'],kmeans_df['gdpp'],hue='KMeans_Clusters',data=kmeans_df) 
plt.title("Child Mortality vs gdpp", fontsize=15)
plt.xlabel("Child Mortality", fontsize=12)
plt.ylabel("gdpp", fontsize=12)
plt.show()

# %%
#visulization of clusters inflation vs gdpp
sns.scatterplot(kmeans_df['inflation'],kmeans_df['gdpp'],hue='KMeans_Clusters',data=kmeans_df) 
plt.title("inflation vs gdpp", fontsize=15)
plt.xlabel("inflation", fontsize=12)
plt.ylabel("gdpp", fontsize=12)
plt.show()

# %%
terbelakang=kmeans_df[kmeans_df['KMeans_Clusters']==0]['country']
maju=kmeans_df[kmeans_df['KMeans_Clusters']==1]['country']
berkembang=kmeans_df[kmeans_df['KMeans_Clusters']==2]['country']

print("Jumlah negara maju",len(under_developing))
print("Jumlah negara berkembang",len(developing))
print("Jumlah negara terbelakang",len(developed))
# Out:
# Jumlah negara maju 47
# Jumlah negara berkembang 84
# Jumlah negara terbelakang 36

# %%
#list negara maju
list(maju)
# Out:
# ['Australia',
#  'Austria',
#  'Bahrain',
#  'Belgium',
#  'Brunei',
#  'Canada',
#  'Cyprus',
#  'Czech Republic',
#  'Denmark',
#  'Finland',
#  'France',
#  'Germany',
#  'Greece',
#  'Iceland',
#  'Ireland',
#  'Israel',
#  'Italy',
#  'Japan',
#  'Kuwait',
#  'Luxembourg',
#  'Malta',
#  'Netherlands',
#  'New Zealand',
#  'Norway',
#  'Portugal',
#  'Qatar',
#  'Singapore',
#  'Slovak Republic',
#  'Slovenia',
#  'South Korea',
#  'Spain',
#  'Sweden',
#  'Switzerland',
#  'United Arab Emirates',
#  'United Kingdom',
#  'United States']

# %%
#list negara berkembang
list(berkembang)
# Out:
# ['Albania',
#  'Algeria',
#  'Antigua and Barbuda',
#  'Argentina',
#  'Armenia',
#  'Azerbaijan',
#  'Bahamas',
#  'Bangladesh',
#  'Barbados',
#  'Belarus',
#  'Belize',
#  'Bhutan',
#  'Bolivia',
#  'Bosnia and Herzegovina',
#  'Brazil',
#  'Bulgaria',
#  'Cambodia',
#  'Cape Verde',
#  'Chile',
#  'China',
#  'Colombia',
#  'Costa Rica',
#  'Croatia',
#  'Dominican Republic',
#  'Ecuador',
#  'Egypt',
#  'El Salvador',
#  'Estonia',
#  'Fiji',
#  'Georgia',
#  'Grenada',
#  'Guatemala',
#  'Guyana',
#  'Hungary',
#  'India',
#  'Indonesia',
#  'Iran',
#  'Jamaica',
#  'Jordan',
#  'Kazakhstan',
#  'Kyrgyz Republic',
#  'Latvia',
#  'Lebanon',
#  'Libya',
#  'Lithuania',
#  'Macedonia, FYR',
#  'Malaysia',
#  'Maldives',
#  'Mauritius',
#  'Micronesia, Fed. Sts.',
#  'Moldova',
#  'Mongolia',
#  'Montenegro',
#  'Morocco',
#  'Myanmar',
#  'Nepal',
#  'Oman',
#  'Panama',
#  'Paraguay',
#  'Peru',
#  'Philippines',
#  'Poland',
#  'Romania',
#  'Russia',
#  'Samoa',
# ...

# %%
#list negara terbelakang
list(terbelakang)
# Out:
# ['Afghanistan',
#  'Angola',
#  'Benin',
#  'Botswana',
#  'Burkina Faso',
#  'Burundi',
#  'Cameroon',
#  'Central African Republic',
#  'Chad',
#  'Comoros',
#  'Congo, Dem. Rep.',
#  'Congo, Rep.',
#  "Cote d'Ivoire",
#  'Equatorial Guinea',
#  'Eritrea',
#  'Gabon',
#  'Gambia',
#  'Ghana',
#  'Guinea',
#  'Guinea-Bissau',
#  'Haiti',
#  'Iraq',
#  'Kenya',
#  'Kiribati',
#  'Lao',
#  'Lesotho',
#  'Liberia',
#  'Madagascar',
#  'Malawi',
#  'Mali',
#  'Mauritania',
#  'Mozambique',
#  'Namibia',
#  'Niger',
#  'Nigeria',
#  'Pakistan',
#  'Rwanda',
#  'Senegal',
#  'Sierra Leone',
#  'South Africa',
#  'Sudan',
#  'Tanzania',
#  'Timor-Leste',
#  'Togo',
#  'Uganda',
#  'Yemen',
#  'Zambia']

# %% [markdown]
# ##### Cek apakah suatu negara masuk kelompok negara yang mana

# %%
for i in developed:
    if i == 'Canada':
      print('Benar', i , 'termasuk dalam list negara maju')
# Out:
# Benar Canada termasuk dalam list negara maju

# %%
for i in developing:
    if i == 'Indonesia':
      print('Benar', i , 'termasuk dalam list negara berkembang')
# Out:
# Benar Indonesia termasuk dalam list negara berkembang

# %%
for i in under_developing:
    if i == 'Madagascar':
      print('Benar', i , 'termasuk dalam list negara terbelakang')
# Out:
# Benar Madagascar termasuk dalam list negara terbelakang
